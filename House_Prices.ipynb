# %%
import pandas as pd
import numpy as np

df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house_df = df[['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'yr_built', 
              'yr_renovated', 'zipcode']]

# %%
# from sklearn.preprocessing import LabelEncoder
# encoder = LabelEncoder()

# house_df['zipcode']= encoder.fit_transform(df['zipcode'])
# house_df

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
house_df.iloc[:, :] = scaler.fit_transform(house_df.iloc[:, :])
house_df
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_12228\1285084275.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_df.iloc[:, :] = scaler.fit_transform(house_df.iloc[:, :])
#           price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0     -0.866717 -0.398737  -1.447464    -0.979835 -0.228321 -0.915427
# 1     -0.005688 -0.398737   0.175607     0.533634 -0.189885  0.936506
# 2     -0.980849 -1.473959  -1.447464    -1.426254 -0.123298 -0.915427
# 3      0.174090  0.676485   1.149449    -0.130550 -0.244014 -0.915427
# 4     -0.081958 -0.398737  -0.149007    -0.435422 -0.169653 -0.915427
# ...         ...       ...        ...          ...       ...       ...
# ...

# %%
x_columns = 10
X = house_df.iloc[:, 1:x_columns].values
y = house_df.iloc[:, 0].values
y
# Out:
# array([-0.86671733, -0.00568792, -0.98084935, ..., -0.37586519,
#        -0.38158814, -0.58588173])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=3)

# %%
#all_models = []
all_models = {}

# %%
from sklearn.linear_model import LinearRegression
model_LR = LinearRegression()
model_LR.fit(X_train, y_train)
y_pred = model_LR.predict(X_test)
score_LR = model_LR.score(X_test, y_test)
print(score_LR)
all_models[model_LR] = score_LR
print(all_models)
# Out:
# 0.5960926448244055
# {LinearRegression(): 0.5960926448244055}

# %%
neighbors = range(1,100)
bestscore_KNN = 0
from sklearn.neighbors import KNeighborsRegressor

for n in neighbors:
    model_KNN = KNeighborsRegressor(n_neighbors = n)
    model_KNN.fit(X_train, y_train)
    score_KNN = model_KNN.score(X_test, y_test)
    #print(score)
    if score_KNN > bestscore_KNN:
        bestscore_KNN = score_KNN
        knn_n = neighbors.index(n)+1
bestscore_KNN

#all_models.append(model_KNN)
all_models[model_KNN] = bestscore_KNN
print(all_models)
# Out:
# {LinearRegression(): 0.5960926448244055, KNeighborsRegressor(n_neighbors=99): 0.6163192582485851}

# %%
from sklearn.preprocessing import PolynomialFeatures
scoresPR = []
for i in range(1,6):
    poly=PolynomialFeatures(degree=i)
    x_poly = poly.fit_transform(X)

    
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    score = model.score(X_test, y_test)
    scoresPR.append(score)
    scorePR = max(scoresPR)

    
bestPoly = scoresPR.index(max(scoresPR)) + 1 # location of max score

print('Max polynomial score is: ',scorePR, "with a value of",bestPoly)
# Out:
# Max polynomial score is:  0.5960926448244055 with a value of 1

# %%
crit = ['mse', 'mae']
depth = [3, 4, 5, 6]
best_score_DT = 0
from sklearn.tree import DecisionTreeRegressor
for i in crit:
    for d in depth:
        t_model = DecisionTreeRegressor(criterion=i, max_depth = d, splitter='best', random_state=0)
        t_model.fit(X_train, y_train)
        y_pred = t_model.predict(X_test)
        score_DT = t_model.score(X_test, y_test)
    
        if score_DT > best_score_DT:
            best_score_DT = score_DT
print(best_score_DT)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# ...

# %%
estimators = [3, 5, 10, 15]
critera = ['mse', 'mae']
best_score_RF = 0

from sklearn.ensemble import RandomForestRegressor
for i in estimators:
    for c in critera:
        model_RF = RandomForestRegressor(n_estimators = i, criterion = c, random_state = 0)
        model_RF.fit(X_train, y_train)
        y_pred_RF = model_RF.predict(X_test)
        score_RF = model_RF.score(X_test, y_test)
        
        if score_RF > best_score_RF:
            best_score_RF = score_RF
best_score_RF
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:403: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:396: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:403: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   warn(
# ...

# %%
# c_value = [0.001,  0.01, 1]
# best_score_SVM = 0
from sklearn.svm import SVR

model_SVR = SVR(kernel = 'linear', max_iter = 1000)
model_SVR.fit(X_train, y_train)
score_SVM_L = model_SVR.score(X_test, y_test)
#         k_n = kernel_value.index(k)
#         c_n = c_value[i]
# if score_SVM >  best_score_SVM:
#     best_score_SVM = score_SVM
print(score_SVM_L)
# Out:
# -0.6751827559855976
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\svm\_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
# c_value = [0.0001, 0.001,  0.01]
# kernel_value = ['rbf', 'linear', 'poly']
# best_score_SVM = 0
from sklearn.svm import SVR

model_SVR = SVR(kernel = 'rbf', C = 1, gamma = 'auto')
model_SVR.fit(X_train, y_train)
score_SVM = model_SVR.score(X_test, y_test)
#         k_n = kernel_value.index(k)
#         c_n = c_value[i]
# if score_SVM >  best_score_SVM:
#     best_score_SVM = score_SVM
print(score_SVM)
# Out:
# 0.5917007141658674

# %%
all_models
# Out:
# {LinearRegression(): 0.5960926448244055,
#  KNeighborsRegressor(n_neighbors=99): 0.6163192582485851}

# %%
house_df = df

# %%
house_df = df[['bedrooms']] == 3
house_df['bathrooms'] = df[['bathrooms']] == 2
house_df['floors'] = df['floors'] == 1
house_df['zipcode'] = df['zipcode'] == 98028
house_df['price'] = df['price']
house_df
# Out:
#        bedrooms  bathrooms  floors  zipcode     price
# 0          True      False    True    False  221900.0
# 1          True      False   False    False  538000.0
# 2         False      False    True     True  180000.0
# 3         False      False    True    False  604000.0
# 4          True       True    True    False  510000.0
# ...         ...        ...     ...      ...       ...
# 21608      True      False   False    False  360000.0
# 21609     False      False   False    False  400000.0
# 21610     False      False   False    False  402101.0
# 21611      True      False   False    False  400000.0
# 21612     False      False   False    False  325000.0
#
# [21613 rows x 5 columns]

# %%
# indexNames = house_df[(house_df['bedrooms'] == False) &  (house_df['bathrooms'] == False) & (house_df['floors'] == False)
#                      & (house_df['zipcode'] == False)].index

indexNames = house_df[house_df['bedrooms'] == False].index
house_df.drop(indexNames, inplace=True)
indexNames2 = house_df[house_df['bathrooms'] == False].index
house_df.drop(indexNames2, inplace=True)
indexNames3 = house_df[house_df['floors'] == False].index
house_df.drop(indexNames3, inplace=True)
indexNames4 = house_df[house_df['zipcode'] == False].index
house_df.drop(indexNames4, inplace=True)
house_df
# Out:
#        bedrooms  bathrooms  floors  zipcode     price
# 6997       True       True    True     True  433000.0
# 8261       True       True    True     True  375000.0
# 8970       True       True    True     True  405000.0
# 19140      True       True    True     True  430000.0

# %%
x_columns = 3
X = house_df.iloc[:, :x_columns].values
y = house_df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
model_hp = LinearRegression()
model_hp.fit(X_train, y_train)
y_pred = model_hp.predict(X_test)
score_hp = model_hp.score(X_test, y_test)
print(y_pred)
# Out:
# [412666.66666667]
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
houseprice_df = df[['bedrooms', 'bathrooms', 'floors', 'zipcode', 'price']]
houseprice_df
# Out:
#        bedrooms  bathrooms  floors  zipcode     price
# 0             3       1.00     1.0    98178  221900.0
# 1             3       2.25     2.0    98125  538000.0
# 2             2       1.00     1.0    98028  180000.0
# 3             4       3.00     1.0    98136  604000.0
# 4             3       2.00     1.0    98074  510000.0
# ...         ...        ...     ...      ...       ...
# 21608         3       2.50     3.0    98103  360000.0
# 21609         4       2.50     2.0    98146  400000.0
# 21610         2       0.75     2.0    98144  402101.0
# 21611         3       2.50     2.0    98027  400000.0
# 21612         2       0.75     2.0    98144  325000.0
#
# [21613 rows x 5 columns]

# %%
x_columns = 3
X = house_df.iloc[:, :x_columns].values
y = house_df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)

# %%
model_hp2 = LinearRegression()
model_hp2.fit(X_train, y_train)
y_pred = model_hp2.predict(X_test)
score_hp2 = model_hp2.score(X_test, y_test)
print(y_pred)
# Out:
# [412666.66666667]
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
model_SVR = SVR(kernel = 'rbf', C = 1, gamma = 'auto')
model_SVR.fit(X_train, y_train)
y_svr_pred = model_SVR.predict(X_train)
score_SVM = model_SVR.score(X_test, y_test)
print(y_svr_pred)
# Out:
# [430000. 430000. 430000.]
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
for i in crit:
    for d in depth:
        hp_t_model = DecisionTreeRegressor(criterion=i, max_depth = d, splitter='best', random_state=0)
        hp_t_model.fit(X_train, y_train)
        hp_y_pred = hp_t_model.predict(X_test)
       
print(hp_y_pred)
# Out:
# [430000.]
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# C:\Users\sachi\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# ...
